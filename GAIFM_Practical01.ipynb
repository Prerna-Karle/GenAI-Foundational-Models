# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/GenAI-Foundational-Models/blob/main/GAIFM_Practical01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch scikit-learn pandas matplotlib seaborn -q

# %%
# Import Libraries

import pandas as pd
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns

from transformers import pipeline

# %% [markdown]
# #A] DISCRIMINATIVE MODEL

# %%
# Load Iris Dataset

iris = load_iris()

# %% [markdown]
# B] IMPLEMENTATION OF GENERATIVE MODEL

# %%
# !pip install transformers torch

# %%
# import the required functions

from transformers import pipeline, set_seed

# %%
# Text generation pipeline

generator = pipeline('text-generation', model='gpt2')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ...

# %%
set_seed(42)

# %%
prompt = "AI will change the future of education by"

# %%
result = generator(
    prompt,
    max_length=50,
    num_return_sequences=1
)

print(result[0]['generated_text'])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
prompt = "Machine Learning helps"

result = generator(
    prompt,
    max_length=60
)

print(result[0]['generated_text'])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
prompt = "Deep Learning enables"

result = generator(
    prompt,
    max_length=60
)

print(result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Deep Learning enables us to predict which of our competitors will win this competition, and to predict our competitors' performance on the next level.
#
# This is going to be one of the most exciting new technologies in the world, and this is something we're really excited about. It will not only make it easier to predict the future of AI, but it will also help us to improve our skills, which will help us to more effectively improve our algorithms. This will also allow us to better understand and improve our learning capabilities, which will allow us to better understand and improve our competitors' performance on the next level.
#
# ...

# %%
prompt = "Data Science helps organizations"

result = generator(
    prompt,
    max_length=60
)

print(result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Data Science helps organizations develop and implement risk management strategies to tackle environmental problems, such as climate change, food security, and water quality. Our mission is to provide research-based research solutions for organizations, governments, and other organizations in the science, technology, engineering, and mathematics (STEM) community.
#
# Academic Programs
#
# Programs are available at the following institutions:
#
# University of Michigan
#
# University of Wisconsin-Madison
#
# University of California, Berkeley
#
# University of Michigan
#
# University of Florida
#
# ...

# %%
prompt = "Natural Language Processing allows computers"

result = generator(
    prompt,
    max_length=70
)

print(result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=70) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Natural Language Processing allows computers to interpret simple expressions and data in language. It also allows for automatic translation of complex words, like "A", "B" and "C".
#
# The languages of language processing are called "language models" because they are based on real-world languages, which are often the most used language models.
#
# The most popular language models are Java and Go.
#
# How are languages different from other languages?
#
# Language models are constructed from simple, easy-to-understand principles that are closely related to those of other languages. The fundamental principles of language models include:
# ...

# %%
prompt = "A student preparing for placements should"

result = generator(
    prompt,
    max_length=70
)

print(result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=70) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# A student preparing for placements should take into account the number of students who have completed their placement.
#
# The students should check with the placement provider to determine if they have been approved for placement.
#
# The placement provider should ensure that the placements are for those who have completed their placements.
#
# The placement provider should ensure that the placements are for students who have completed their placements.
#
# The placement provider should ensure that the placements are for students who have completed their placements.
#
# ...
